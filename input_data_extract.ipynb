# %%
import ee
import geemap 
import geopandas as gpd
from datetime import datetime
import numpy as np
import rasterio
import pandas as pd
import requests

# %%
ee.Authenticate(force=True)
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Hq4wZs_A3B0wtaD2JYmrThLZTneZSmxDNd58ezOG-98&tc=QvGgtBWbUhFPF3Q8bEriNMQQUjsj7ziVGiMpJQP36c4&cc=4MnXU7qW22oQlo3wRKiWpHQcVdD2F-QZWvNLYhoDvGQ>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Hq4wZs_A3B0wtaD2JYmrThLZTneZSmxDNd58ezOG-98&tc=QvGgtBWbUhFPF3Q8bEriNMQQUjsj7ziVGiMpJQP36c4&cc=4MnXU7qW22oQlo3wRKiWpHQcVdD2F-QZWvNLYhoDvGQ</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %% [markdown]
# ### Download Sentinel-1 Images

# %%
def load_shapefile(file_path):
    gdf = gpd.read_file(file_path)
    geom = gdf.geometry.union_all()
    return ee.Geometry(geom.__geo_interface__)  # convert to ee.Geometry

# Function to check if an image has >99% valid pixels
def is_valid_image(image, roi):
    mask = image.mask().clip(roi)
    valid_pixel_count = mask.reduceRegion(
        reducer=ee.Reducer.sum(),
        geometry=roi,
        scale=10,
        maxPixels=1e13
    ).values().get(0)
    
    total_pixel_count = ee.Number(image.unmask().clip(roi).reduceRegion(
        reducer=ee.Reducer.count(),
        geometry=roi,
        scale=10,
        maxPixels=1e13
    ).values().get(0))
    
    valid_ratio = ee.Number(valid_pixel_count).divide(total_pixel_count).multiply(100)
    return valid_ratio.gte(99)  # True if ≥99% valid pixels

# Function to get the nearest Sentinel-1 image with specified orbit pass
def get_nearest_sentinel1(roi, target_date, orbit_pass):
    collection = ee.ImageCollection('COPERNICUS/S1_GRD') \
        .filterBounds(roi) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
        .filter(ee.Filter.eq('instrumentMode', 'IW')) \
        .filter(ee.Filter.eq('orbitProperties_pass', orbit_pass))  # Filter ASCENDING or DESCENDING images

    start_date = ee.Date(target_date).advance(-3, 'day')
    end_date = ee.Date(target_date).advance(3, 'day')
    
    filtered = collection.filterDate(start_date, end_date)
    # Check if the filtered collection is empty
    if filtered.size().getInfo() == 0:
        print(f"No images found for date range {start_date.format('YYYY-MM-dd').getInfo()} to {end_date.format('YYYY-MM-dd').getInfo()}")
        return None  # No valid images found

    images = filtered.sort('system:time_start').toList(filtered.size())


    best_image = None
    min_diff = None

    for i in range(images.size().getInfo()):
        img = ee.Image(images.get(i)).select(['VV', 'VH']).toFloat()
        img_date = ee.Date(img.get('system:time_start'))
        diff = img_date.difference(ee.Date(target_date), 'day').abs()
        is_later = img_date.difference(ee.Date(target_date), 'day').gt(0)

        if best_image is None or diff.lt(min_diff).getInfo() or (diff.eq(min_diff).getInfo() and is_later.getInfo()):
            if is_valid_image(img, roi).getInfo():
                best_image = img
                min_diff = diff

    return best_image

# Function to export image to Google Drive
def export_image(image, roi, filename, site):
    task = ee.batch.Export.image.toDrive(
        image=image.clip(roi).toFloat(),
        description=filename,
        folder= site,  # Change folder as needed
        fileNamePrefix=filename,
        scale=10,
        region=roi.bounds(),
        crs = 'EPSG:4326',   
        maxPixels = 1e13,
        fileFormat='GeoTIFF'
    )
    task.start()
    print(f"Export started: {filename}")

# Example usage
# SCAN_Kemole_Gulch
# SCAN_Kukuihaele
# Mana_House
# SCAN_Silver_Sword
# SCAN_Waimea_Plain
# TAHMO_CRIG_(Soil_Moisture_Station_1)
# TAHMO_CRIG_(Soil_Moisture_Station_2)
site = 'TAHMO_CRIG_(Soil_Moisture_Station_2)'
shapefile_path = f"shapefiles/{site}_smap/{site}_smap_polygons.shp"
csv_path = f"daily_smap/{site}_smap.csv"
roi = load_shapefile(shapefile_path)
dates = []  # List of target dates

df = pd.read_csv(csv_path)
valid_dates = df.dropna(subset=['smap_soil_moisture_am'])

# valid_dates
for index, row in valid_dates.iterrows():
    dates.append(row['time'])
print(len(dates))
for date in dates:
    for orbit in ['DESCENDING', 'ASCENDING']:
        image = get_nearest_sentinel1(roi, date, orbit)
        if image:
            print(f"Found Sentinel-1 {orbit} image for {date}")
            export_image(image, roi, f"{site}_S1_{date}_{orbit}", site)
        else:
            print(f"No valid {orbit} Sentinel-1 data from {date}-3 to {date}+3 days.")

# %% [markdown]
# ### Download NDVI 10 m calculated from Sentinel-2

# %%
import ee
import geopandas as gpd
import pandas as pd
import os

# Load shapefile as ROI
def load_shapefile(file_path):
    gdf = gpd.read_file(file_path)
    geom = gdf.geometry.unary_union
    return ee.Geometry(geom.__geo_interface__)

def is_valid(image, roi, threshold = 0.5):
    valid_pixel_mask = image.mask().reduceRegion(
        reducer = ee.Reducer.sum(),
        geometry = roi,
        scale = 10,
        bestEffort = True
    ).getNumber('NDVI')

    # Count total pixels 
    total_pixels = image.unmask().reduceRegion(
        reducer = ee.Reducer.count(),
        geometry = roi,
        scale = 10,
        bestEffort = True
    ).getNumber('NDVI')

    fraction_valid = valid_pixel_mask.divide(total_pixels)

    return fraction_valid.gte(threshold)



# Get Sentinel-2 collection for a specific target_day
def get_sentinel_collection(target_day, roi):
    s_date = ee.Date(target_day).advance(-4, 'day')
    e_date = ee.Date(target_day).advance(4, 'day')

    cs_plus = ee.ImageCollection('GOOGLE/CLOUD_SCORE_PLUS/V1/S2_HARMONIZED')
    qa_band = 'cs'
    clear_threshold = 0.5

    sentinel2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')\
                    .filterBounds(roi)\
                    .filterDate(s_date, e_date)\
                    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 50))\
                    .linkCollection(cs_plus, [qa_band])

    cloud_masked_sentinel2 = sentinel2.map(lambda img: img.updateMask(img.select(qa_band).gte(clear_threshold)).clip(roi))

    return cloud_masked_sentinel2  

# Separate Sentinel collection into Cloud-Free and Cloudy collections
def separate_collections(ndvi_collection):
    cloud_free_collection = ndvi_collection.filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 10))
    cloudy_collection = ndvi_collection.filter(ee.Filter.gt('CLOUDY_PIXEL_PERCENTAGE', 10))
    return {'cloudFree': cloud_free_collection, 'cloudy': cloudy_collection}

# def compute_mean_ndvi(image_collection):
#     ndvi_collection = image_collection.map(lambda img: img.normalizedDifference(['B8', 'B4']).rename('NDVI'))
#     return ndvi_collection.mean()


def compute_mean_ndvi(image_collection):
    """Compute mean NDVI and handle empty collections."""
    has_images = image_collection.size().gt(0)

    def compute():
        mean_nvdi = image_collection.mean().normalizedDifference(['B8', 'B4']).rename('NDVI')
    
        # ndvi_collection = image_collection.map(lambda img: img.normalizedDifference(['B8', 'B4']).rename('NDVI'))
        # valid_pixel_count = ndvi_collection.count()
        # mean_nvdi = mean_nvdi.updateMask(valid_pixel_count.gt(0))
        return mean_nvdi

    ndvi_image = ee.Algorithms.If(has_images, compute(), None)
    return ee.Image(ndvi_image) if ndvi_image else None 

# Download image to local storage
def download_image(image, ee_geom, output_filepath):
    """
    Download a GEE image using getDownloadURL.
    :param image: ee.Image to download.
    :param ee_geom: ee.Geometry used as region.
    :param output_filepath: Local filepath to save the image.
    """
    if image is None:
        print("Error: The image is None. Skipping download.")
        return
    
    try:
        # Ensure image is not empty before downloading
        image_size = image.bandNames().size().getInfo()
        if image_size == 0:
            print("Error: The image has no bands. Skipping download.")
            return
        
        # Replace no-data pixels with nodata_value
        nodata_value = -9999
        image = image.unmask(nodata_value)

        params = {
            'scale': 10,
            'region': ee_geom.bounds().getInfo(),
            'filePerBand': False,
            'format': 'GeoTIFF'
        }
        
        download_url = image.getDownloadURL(params)
        print(f"Downloading from URL: {download_url}")
        response = requests.get(download_url, stream=True)

        if response.status_code == 200:
            temp_filepath = output_filepath + '.tmp'
            with open(temp_filepath, 'wb') as f:
                for chunk in response.iter_content(chunk_size=1024):
                    if chunk:
                        f.write(chunk)
            print(f"Downloaded image saved to {temp_filepath}")
        
            with rasterio.open(temp_filepath) as src:
                data = src.read(1)
                data[data == nodata_value] = np.nan 
                profile = src.profile

            profile.update(nodata = np.nan)

            with rasterio.open(output_filepath, 'w', **profile) as dst:
                dst.write(data, 1)

            os.remove(temp_filepath)
            print(f"Converted no-data values to NaN and saved to {output_filepath}")
        else:
            print(f"Failed to download image, status code: {response.status_code}")

    except Exception as e:
        print(f"Error downloading image: {e}")

# Main execution
site = 'TAHMO_CRIG_(Soil_Moisture_Station_2)'
shapefile_path = f"shapefiles/{site}_smap/{site}_smap_polygons.shp"
roi = load_shapefile(shapefile_path)
csv_path = f"daily_smap/{site}_smap.csv"

df = pd.read_csv(csv_path)
valid_dates = df.dropna(subset=['smap_soil_moisture_am'])
dates = valid_dates['time'].tolist()
os.makedirs(f"./downloads1/{site}", exist_ok=True)
for target_day in dates:
    print(f"Processing {target_day}...")

    # Load Sentinel-2 and separate collections
    sentinel_collection = get_sentinel_collection(target_day, roi)
    collections = separate_collections(sentinel_collection)

    # Compute NDVI for each collection
    ndvi_cloudFree = compute_mean_ndvi(collections['cloudFree'])
    if ndvi_cloudFree:
        download_image(ndvi_cloudFree, roi, f"downloads1/{site}/ndvi_noncloud_{site}_{target_day}.tif")
    ndvi_cloudy = compute_mean_ndvi(collections['cloudy'])
    if ndvi_cloudy:
        if is_valid(ndvi_cloudy, roi):
            download_image(ndvi_cloudy, roi, f"downloads1/{site}/ndvi_cloudy_{site}_{target_day}.tif")
        else:
            print("Skipping cloudy image {date} due to low valid pixel count.")

print("All downloads completed.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /tmp/ipykernel_5166/1535105245.py:9: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geom = gdf.geometry.unary_union
# Processing 2020-01-02...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/d261147cd8a28445df8f17329d160be8-963ef806df42a79325892e9384520c0d:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-02.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-02.tif
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-01-10...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/57ffd27d3e5da30726b354e3ad5f9b9d-183107ed8cb346a5f165b9f78ee74a65:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-10.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-10.tif
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-01-18...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5dd40092e12d9bd07dde24750b48f463-3e39735782f2c7f9fd7cf14588f98220:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-18.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-18.tif
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-01-26...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/993c35394dc8affc8b464c28327ab209-32764445322876973510a2c3c098c4e6:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-26.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-26.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/f505b9a7df80146f7179f3a02d87904b-f21843baf6941501628f6adbab50ea86:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-26.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-01-26.tif
# Processing 2020-02-03...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/421afe1312611aef22445d7c2e44aa8f-8f9c6dde5caf121f3de8bb0eb3348e05:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-03.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-03.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/6acc45e08b5914a5c10386075e320af6-07e9188abc3e6780d2516b09a3b12659:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-03.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-03.tif
# Processing 2020-02-19...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/f175ef40a0d0d3b6475f2f8208734c92-fef269cf75169292a7b41328fcd41648:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-19.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-19.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/e40c76ce852b1751e11d8c37dae1f5b1-c318210d8200c2c6c43146c400e49500:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-19.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-02-19.tif
# Processing 2020-03-06...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/af09c7e37ad0626f1af8cc45a088e26d-d04a6a32e9aaf62d77cabc9732538322:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-06.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-06.tif
# Processing 2020-03-14...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/44f5a5af87e12d4f9ca758f66eeb098e-ef34e5e88fb16f535af9dd74dc4ae943:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-14.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-14.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/f4b87ef0390489998f8d75f3fb91f717-91b6726313186223613aa12b51c2e409:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-14.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-14.tif
# Processing 2020-03-22...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/47f2bc2dd8715e80e87c0d22c4b42894-304ff297846a4a49ec76659328bfe820:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-22.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-22.tif
# Processing 2020-03-30...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/416b5167838d13929ed219922eb05243-34b670e5da2d627850297965c725a9b7:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-30.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-03-30.tif
# Processing 2020-04-07...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-04-15...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/752c8b83918244e8265a9519f2f10358-2ea40d24962b9353011f0e27ef6b5ed9:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-04-15.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-04-15.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/70338b88a355a4faca03a59adad15a84-643c0a909f29d5a740a68e4036a3ca96:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-04-15.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-04-15.tif
# Processing 2020-05-01...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/7ac40bb7d36eb01b8a3589414c22747f-e5dbfaeac6a9c6621574629eab142ff3:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-01.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-01.tif
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-05-09...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/44337c74d8b7265ef144d23d1c0303f6-c1b1d408a1636d7acf4035789160a923:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-09.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-09.tif
# Processing 2020-05-17...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/bfdf956337a10e773fbbf86cbdf89f1a-f708c2b94b90f5c55d8fa89e4f36cacf:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-17.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-17.tif
# Processing 2020-05-25...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5e70a23ac2245da245a248af77636b9a-4903eca287c04fe12f0155f72eea7879:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-25.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-05-25.tif
# Processing 2020-06-02...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/665a5309ad54a495e6a1e62f72fe97dc-7d5f443d96d3f5667e934c2f4423e88f:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-06-02.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-06-02.tif
# Processing 2020-06-18...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/4d41d2139c9103c89e26c2197d5658e7-51862d5b394191794b047d5f921ffbba:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-06-18.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-06-18.tif
# Processing 2020-06-26...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-07-04...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-07-12...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-07-20...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-08-05...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/590ea18600a9ab27662cf6d2cf73eba3-70e27fe34b8b3faa3575e97f768e20df:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-05.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-05.tif
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-08-13...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5d864b7c4e240bc186722dc76b48f5bf-5e7c29d5a2ce43662fdac46190bc71c1:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-13.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-13.tif
# Processing 2020-08-21...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/68b92fbaeaab697b6b8a6fcf91ea56f2-9355b0f260d9b4d423dbca94d8b9d73f:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-21.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-08-21.tif
# Processing 2020-08-29...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-09-06...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-09-14...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-09-22...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-09-30...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/1f2cf0df5d6fc6207353fd501f0e1546-d2ad7d5d89713818eaad838c57f15567:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-09-30.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-09-30.tif
# Processing 2020-10-08...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2020-10-16...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5e9dba3b3216102ffd8f6e7e48b2cfa9-fde1fd856a1d9fe7be5759175d3617d6:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-10-16.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-10-16.tif
# Processing 2020-10-24...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/3de1b460e0a271c8d439947152dfecf5-e5fbc72ee60a31b9753d04dc699bb1c1:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-10-24.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-10-24.tif
# Processing 2020-11-01...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/cb4ebbb0c8a8fde6451e27713d2f8118-d71e8596b0b2d9ed8e6a09ecff75c741:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-01.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-01.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/b741fea2e09b910b5d6dd9e9bf2f0f9d-ea8b5f076e29e588a2465930d5519ac8:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-01.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-01.tif
# Processing 2020-11-09...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5b813c277bc42a1ae9212d5e31f50e70-9ed0f3affa6f1480ade1ec909d55e9a5:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-09.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-09.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/1c5fdb36412968d457ccf0740ed7df1c-b07efa1f34e3533c16b60470a5841e3a:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-09.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-09.tif
# Processing 2020-11-17...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/6fd950653ce5835d00228e6e69617a32-80889096ae8d1e7a15e73c988239b41f:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-17.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-17.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/6fae228b03944bd63ff0cfd60932f42a-e16592c9d881e0689696af0011e5c6d0:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-17.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-17.tif
# Processing 2020-11-25...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/73b910c2b266909a7cbaac975ff152c6-6011e7794f456ae306163e52746e55cc:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-25.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-11-25.tif
# Processing 2020-12-11...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/9a77de52febb54cf018a6395c4a8a667-92a57bce2ce1ccf8aabe425f25481292:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-11.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-11.tif
# Processing 2020-12-19...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/8c6b2567fcf6fe0c7def1a30c18878d4-7c9dfd27c493168f5c69672384f7a7b6:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-19.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-19.tif
# Processing 2020-12-27...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/3a5dd9e1050a0f24e193e41e56040a95-7b5aae1eb37fde42e44c571cf5efbe63:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-27.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-27.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/495b937c6bc4ae26043b73fe08240bf3-f889db6a0d9d9a004b3e3b4f346849ca:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-27.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2020-12-27.tif
# Processing 2021-01-04...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/b789271df7f76871b4b59c65c77ab9dc-2105de595c7362bff59cd8b51024b366:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-04.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-04.tif
# Processing 2021-01-12...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/fecc9afb6d72ef3bc4831cd86d2da535-f07845b1c8e0404977d0b84d54642197:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-12.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-12.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/70fe7104823e8ff47db6ff7a7e43fc8e-9dadb5764e21a6d5a7d1e86ddb408143:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-12.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-12.tif
# Processing 2021-01-20...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/15fb0239f808f4c09171684cae4121d7-0243062e130a46b38ca87569c47b791c:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-20.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-20.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/f0c558df995b63c0371ce2f68d28dd5a-ef8032e49c322f7418dc0f2b993bfd1c:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-20.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-20.tif
# Processing 2021-01-28...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/33faa44cd6b00204eb1b8850463ecb0f-5b1637caeb270835961ea96f261745a8:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-28.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-28.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/e1791736ebe4407c2837d515684b83f8-9bff1eca75d4bf21b9082d64c3c3c277:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-28.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-01-28.tif
# Processing 2021-02-05...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/815917d33530bdb7ac7e6bfc57a2d393-2b765f33a9aa20dfd9efe5c47d99ea49:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-05.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-05.tif
# Processing 2021-02-13...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/5d43954667c530a1eb1f89dc3e1f1f69-465f8b7832ab4685961394842f061de1:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-13.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-13.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/9a79d198a33663caf295a59acf69dafc-c45cf3ce3a3c0bec4ca3708950cdad74:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-13.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-13.tif
# Processing 2021-02-21...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/3d41b10f1897666b86de2d8b39a6e8e7-f7c4710ee466e4663c91850bed281da2:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-21.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-02-21.tif
# Processing 2021-03-01...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/af5e2764d576c610f747a6a6734289fd-d5a9d09a236cd0d3e25f66d050b824c2:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-01.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-01.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/ef2a0ed5164054d161690fd06a072cc5-4b9b99db907511f276cd68d02c45ba83:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-01.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-01.tif
# Processing 2021-03-09...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/f8b920b78e21fc23bc18076bb74cf3ae-d8a0291bb0d0f332b69c8b96cc68ba4b:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-09.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-09.tif
# Processing 2021-03-17...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-03-25...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/965344600aae4c97bbde05a051ffb6ff-79201e43017ea947d1dad82f47471b9a:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-25.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-03-25.tif
# Processing 2021-04-02...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-04-10...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/726da443087d64dabe53e2fb64a360f3-ec50ed1ac8ce01a664a146a929fe60c4:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-10.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-10.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/589a908c799f0535a86dda4181a20e17-61cca140651c1d26fd901f26e7ded17c:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-10.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-10.tif
# Processing 2021-04-18...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/9d07d2103ccbcd6201cd741f9d05833a-b6d4afa9bd03f89c035bf17fe84b031b:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-18.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-18.tif
# Processing 2021-04-26...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/e5645ad25ee2f263c27887ccfa9cdb2b-698381b6127dae176893955482c83f11:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-26.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-04-26.tif
# Processing 2021-05-04...
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/34ac1b3539cb5e5378b3c2cb30a3cf4c-1d479967f52f7cce6a752d75d09ff9b5:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-04.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_noncloud_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-04.tif
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/76ad2d67d22e6ea73b73df0031d30164-20a6727a8b6c62c0510ebc7556b13fc8:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-04.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-04.tif
# Processing 2021-05-12...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/c8ad05a3176ab1a4414dba5245bfe67d-50b4e537d40f759fa41184f4191bedec:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-12.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-12.tif
# Processing 2021-05-20...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/3bfe6e149c9ffd1f48e8b1e5c071f180-4020da426d9bc77cda8212b6106a8dd5:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-20.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-20.tif
# Processing 2021-05-28...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/af3f9c3fdcef3a2a12f76cddedcf87f1-ad1b6cb67a1059249d3f49067b3ac003:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-28.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-05-28.tif
# Processing 2021-06-05...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/47a72405188686c6fed4b02a2db869db-cc31e3b672fe9626dda9fc7659e386b4:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-06-05.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-06-05.tif
# Processing 2021-06-13...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/c4a02286fdba1976707fca0d9e16e996-0e6cb06e388e1360aa3e3ba1f1873fb7:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-06-13.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-06-13.tif
# Processing 2021-06-21...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-06-29...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-07-07...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/abd557dc31561af0bb2e1a3410f6719c-f739c315ebe8f09dcae7c1a0b2b66b35:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-07.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-07.tif
# Processing 2021-07-15...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-07-23...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/1da4f868834d1ebbaf385727e0851e8a-46912812620417f718f6aeb38ab26146:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-23.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-23.tif
# Processing 2021-07-31...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/64235de471f14ffdbb7d12a36d29cdba-2e5252ecf8cc04505a4482f6b2c97537:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-31.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-07-31.tif
# Processing 2021-08-08...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/7c84d7be5bd2452e5b3857137ac196fd-c2b891945fce902df220ee66f38d882a:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-08-08.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-08-08.tif
# Processing 2021-08-16...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-08-24...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-09-01...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Processing 2021-09-17...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/08ed6fa45c1288a617238eddfb7e7ea6-3d681f2e9df5c7a3184a7cf95cf29e9a:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-09-17.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-09-17.tif
# Processing 2021-09-25...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/a8b7f0c21aa2abec8e6d427369879d1a-62c633d026251cbd9751ebd221d63354:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-09-25.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-09-25.tif
# Processing 2021-10-03...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/68e09ad2eeae1de4ded041699e539d54-13961719bc1382f74b434d984803eabb:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-10-03.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2021-10-03.tif
# Processing 2022-01-15...
# Error downloading image: Image.bandNames: Parameter 'image' is required and may not be null.
# Downloading from URL: https://earthengine.googleapis.com/v1/projects/113350737922/thumbnails/3d801eb938aedaff5a40f9b09547e020-2f546a64311065b087c63aac9cfc9e99:getPixels
# Downloaded image saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2022-01-15.tif.tmp
# Converted no-data values to NaN and saved to downloads1/TAHMO_CRIG_(Soil_Moisture_Station_2)/ndvi_cloudy_TAHMO_CRIG_(Soil_Moisture_Station_2)_2022-01-15.tif
# All downloads completed.

# %% [markdown]
# ### Download NVDI

# %%
def load_shapefile(file_path):
    gdf = gpd.read_file(file_path)
    geom = gdf.geometry.unary_union
    return ee.Geometry(geom.__geo_interface__)  # convert to ee.Geometry

# Function to check if an image has >99% valid pixels
def is_valid_image(image, roi):
    mask = image.mask().clip(roi)
    valid_pixel_count = mask.reduceRegion(
        reducer=ee.Reducer.sum(),
        geometry=roi,
        scale=500,
        maxPixels=1e13
    ).values().get(0)
    
    total_pixel_count = ee.Number(image.unmask().clip(roi).reduceRegion(
        reducer=ee.Reducer.count(),
        geometry=roi,
        scale=500,
        maxPixels=1e13
    ).values().get(0))
    
    valid_ratio = ee.Number(valid_pixel_count).divide(total_pixel_count).multiply(100)
    return valid_ratio.gte(99)  # True if ≥99% valid pixels

# Function to get the nearest Sentinel-1 image with specified orbit pass
def get_nearest_viirs(roi, target_date):
    collection = ee.ImageCollection('NASA/VIIRS/002/VNP13A1') \
        .filterBounds(roi)

    start_date = ee.Date(target_date).advance(-4, 'day')
    end_date = ee.Date(target_date).advance(4, 'day')
    
    filtered = collection.filterDate(start_date, end_date)
    # Check if the filtered collection is empty
    if filtered.size().getInfo() == 0:
        print(f"No images found for date range {start_date.format('YYYY-MM-dd').getInfo()} to {end_date.format('YYYY-MM-dd').getInfo()}")
        return None  # No valid images found

    images = filtered.sort('system:time_start').toList(filtered.size())


    best_image = None
    min_diff = None

    for i in range(images.size().getInfo()):
        img = ee.Image(images.get(i)).select('NDVI').toFloat()
        img_date = ee.Date(img.get('system:time_start'))
        diff = img_date.difference(ee.Date(target_date), 'day').abs()
        is_later = img_date.difference(ee.Date(target_date), 'day').gt(0)

        if best_image is None or diff.lt(min_diff).getInfo() or (diff.eq(min_diff).getInfo() and is_later.getInfo()):
            if is_valid_image(img, roi).getInfo():
                best_image = img
                min_diff = diff

    return best_image

# Function to export image to Google Drive
def export_image(image, roi, filename, site):
    task = ee.batch.Export.image.toDrive(
        image=image.toFloat(),
        description=filename,
        folder= 'NDVI_'+site,  # Change folder as needed
        fileNamePrefix=filename,
        scale=500,
        region=roi.bounds(),
        crs = 'EPSG:4326',   
        maxPixels = 1e13,
        fileFormat='GeoTIFF'
    )
    task.start()
    print(f"Export started: {filename}")

# Example usage
# SCAN_Kemole_Gulch oke
# SCAN_Kukuihaele none
# SCAN_Mana_House oke
# SCAN_Silver_Sword
# SCAN_Waimea_Plain
# TAHMO_CRIG_(Soil_Moisture_Station_1)
# TAHMO_CRIG_(Soil_Moisture_Station_2)
site = 'SCAN_Silver_Sword'
shapefile_path = f"shapefiles/{site}_smap/{site}_smap_polygons.shp"
csv_path = f"daily_smap/{site}_smap.csv"
roi = load_shapefile(shapefile_path)
dates = []  # List of target dates

df = pd.read_csv(csv_path)
valid_dates = df.dropna(subset=['smap_soil_moisture_am'])

for index, row in valid_dates.iterrows():
    dates.append(row['time'])

print(len(dates))

for date in dates:
    image = get_nearest_viirs(roi, date)
    if image:
        print(f"Found VIIRS image for {date}")
        export_image(image, roi, f"{site}_VIIRS_{date}", site)
    else:
            print(f"No valid VIIRS data from {date}-4 to {date}+4 days.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /tmp/ipykernel_14644/1394914834.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geom = gdf.geometry.unary_union
# 176
# Found VIIRS image for 2020-01-06
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-06
# Found VIIRS image for 2020-01-09
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-09
# Found VIIRS image for 2020-01-14
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-14
# Found VIIRS image for 2020-01-17
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-17
# Found VIIRS image for 2020-01-22
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-22
# Found VIIRS image for 2020-01-25
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-25
# Found VIIRS image for 2020-01-30
# Export started: SCAN_Silver_Sword_VIIRS_2020-01-30
# Found VIIRS image for 2020-02-02
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-02
# Found VIIRS image for 2020-02-07
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-07
# Found VIIRS image for 2020-02-10
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-10
# Found VIIRS image for 2020-02-15
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-15
# Found VIIRS image for 2020-02-18
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-18
# Found VIIRS image for 2020-02-23
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-23
# Found VIIRS image for 2020-02-26
# Export started: SCAN_Silver_Sword_VIIRS_2020-02-26
# Found VIIRS image for 2020-03-02
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-02
# Found VIIRS image for 2020-03-05
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-05
# Found VIIRS image for 2020-03-10
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-10
# Found VIIRS image for 2020-03-13
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-13
# Found VIIRS image for 2020-03-18
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-18
# Found VIIRS image for 2020-03-21
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-21
# Found VIIRS image for 2020-03-26
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-26
# Found VIIRS image for 2020-03-29
# Export started: SCAN_Silver_Sword_VIIRS_2020-03-29
# Found VIIRS image for 2020-04-03
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-03
# Found VIIRS image for 2020-04-06
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-06
# Found VIIRS image for 2020-04-11
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-11
# Found VIIRS image for 2020-04-19
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-19
# Found VIIRS image for 2020-04-22
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-22
# Found VIIRS image for 2020-04-27
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-27
# Found VIIRS image for 2020-04-30
# Export started: SCAN_Silver_Sword_VIIRS_2020-04-30
# Found VIIRS image for 2020-05-05
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-05
# Found VIIRS image for 2020-05-08
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-08
# Found VIIRS image for 2020-05-13
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-13
# Found VIIRS image for 2020-05-16
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-16
# Found VIIRS image for 2020-05-21
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-21
# Found VIIRS image for 2020-05-24
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-24
# Found VIIRS image for 2020-05-29
# Export started: SCAN_Silver_Sword_VIIRS_2020-05-29
# Found VIIRS image for 2020-06-06
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-06
# Found VIIRS image for 2020-06-09
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-09
# Found VIIRS image for 2020-06-14
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-14
# Found VIIRS image for 2020-06-17
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-17
# Found VIIRS image for 2020-06-25
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-25
# Found VIIRS image for 2020-06-30
# Export started: SCAN_Silver_Sword_VIIRS_2020-06-30
# Found VIIRS image for 2020-07-03
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-03
# Found VIIRS image for 2020-07-08
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-08
# Found VIIRS image for 2020-07-16
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-16
# Found VIIRS image for 2020-07-19
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-19
# Found VIIRS image for 2020-07-24
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-24
# Found VIIRS image for 2020-07-27
# Export started: SCAN_Silver_Sword_VIIRS_2020-07-27
# Found VIIRS image for 2020-08-01
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-01
# Found VIIRS image for 2020-08-04
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-04
# Found VIIRS image for 2020-08-09
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-09
# Found VIIRS image for 2020-08-12
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-12
# Found VIIRS image for 2020-08-17
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-17
# Found VIIRS image for 2020-08-20
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-20
# Found VIIRS image for 2020-08-25
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-25
# Found VIIRS image for 2020-08-28
# Export started: SCAN_Silver_Sword_VIIRS_2020-08-28
# Found VIIRS image for 2020-09-02
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-02
# Found VIIRS image for 2020-09-05
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-05
# Found VIIRS image for 2020-09-10
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-10
# Found VIIRS image for 2020-09-13
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-13
# Found VIIRS image for 2020-09-18
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-18
# Found VIIRS image for 2020-09-21
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-21
# Found VIIRS image for 2020-09-26
# Export started: SCAN_Silver_Sword_VIIRS_2020-09-26
# Found VIIRS image for 2020-10-04
# Export started: SCAN_Silver_Sword_VIIRS_2020-10-04
# Found VIIRS image for 2020-10-07
# Export started: SCAN_Silver_Sword_VIIRS_2020-10-07
# Found VIIRS image for 2020-10-12
# Export started: SCAN_Silver_Sword_VIIRS_2020-10-12
# Found VIIRS image for 2020-10-15
# Export started: SCAN_Silver_Sword_VIIRS_2020-10-15
# Found VIIRS image for 2020-10-23
# Export started: SCAN_Silver_Sword_VIIRS_2020-10-23
# Found VIIRS image for 2020-11-05
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-05
# Found VIIRS image for 2020-11-08
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-08
# Found VIIRS image for 2020-11-13
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-13
# Found VIIRS image for 2020-11-16
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-16
# Found VIIRS image for 2020-11-21
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-21
# Found VIIRS image for 2020-11-24
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-24
# Found VIIRS image for 2020-11-29
# Export started: SCAN_Silver_Sword_VIIRS_2020-11-29
# Found VIIRS image for 2020-12-02
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-02
# Found VIIRS image for 2020-12-07
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-07
# Found VIIRS image for 2020-12-10
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-10
# Found VIIRS image for 2020-12-15
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-15
# Found VIIRS image for 2020-12-18
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-18
# Found VIIRS image for 2020-12-23
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-23
# Found VIIRS image for 2020-12-26
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-26
# Found VIIRS image for 2020-12-31
# Export started: SCAN_Silver_Sword_VIIRS_2020-12-31
# Found VIIRS image for 2021-01-03
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-03
# Found VIIRS image for 2021-01-08
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-08
# Found VIIRS image for 2021-01-11
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-11
# Found VIIRS image for 2021-01-16
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-16
# Found VIIRS image for 2021-01-19
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-19
# Found VIIRS image for 2021-01-24
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-24
# Found VIIRS image for 2021-01-27
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-27
# Found VIIRS image for 2021-02-01
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-01
# Found VIIRS image for 2021-02-04
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-04
# Found VIIRS image for 2021-02-09
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-09
# Found VIIRS image for 2021-02-12
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-12
# Found VIIRS image for 2021-02-17
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-17
# Found VIIRS image for 2021-02-20
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-20
# Found VIIRS image for 2021-02-25
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-25
# Found VIIRS image for 2021-02-28
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-28
# Found VIIRS image for 2021-03-05
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-05
# Found VIIRS image for 2021-03-08
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-08
# Found VIIRS image for 2021-03-13
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-13
# Found VIIRS image for 2021-03-16
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-16
# Found VIIRS image for 2021-03-21
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-21
# Found VIIRS image for 2021-03-24
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-24
# Found VIIRS image for 2021-03-29
# Export started: SCAN_Silver_Sword_VIIRS_2021-03-29
# Found VIIRS image for 2021-04-01
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-01
# Found VIIRS image for 2021-04-06
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-06
# Found VIIRS image for 2021-04-09
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-09
# Found VIIRS image for 2021-04-14
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-14
# Found VIIRS image for 2021-04-17
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-17
# Found VIIRS image for 2021-04-22
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-22
# Found VIIRS image for 2021-04-25
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-25
# Found VIIRS image for 2021-04-30
# Export started: SCAN_Silver_Sword_VIIRS_2021-04-30
# Found VIIRS image for 2021-05-03
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-03
# Found VIIRS image for 2021-05-08
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-08
# Found VIIRS image for 2021-05-11
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-11
# Found VIIRS image for 2021-05-16
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-16
# Found VIIRS image for 2021-05-19
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-19
# Found VIIRS image for 2021-05-24
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-24
# Found VIIRS image for 2021-05-27
# Export started: SCAN_Silver_Sword_VIIRS_2021-05-27
# Found VIIRS image for 2021-06-01
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-01
# Found VIIRS image for 2021-06-04
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-04
# Found VIIRS image for 2021-06-12
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-12
# Found VIIRS image for 2021-06-20
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-20
# Found VIIRS image for 2021-06-25
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-25
# Found VIIRS image for 2021-06-28
# Export started: SCAN_Silver_Sword_VIIRS_2021-06-28
# Found VIIRS image for 2021-07-03
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-03
# Found VIIRS image for 2021-07-06
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-06
# Found VIIRS image for 2021-07-11
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-11
# Found VIIRS image for 2021-07-14
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-14
# Found VIIRS image for 2021-07-19
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-19
# Found VIIRS image for 2021-07-22
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-22
# Found VIIRS image for 2021-07-27
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-27
# Found VIIRS image for 2021-07-30
# Export started: SCAN_Silver_Sword_VIIRS_2021-07-30
# Found VIIRS image for 2021-08-04
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-04
# Found VIIRS image for 2021-08-07
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-07
# Found VIIRS image for 2021-08-12
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-12
# Found VIIRS image for 2021-08-15
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-15
# Found VIIRS image for 2021-08-20
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-20
# Found VIIRS image for 2021-08-23
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-23
# Found VIIRS image for 2021-08-28
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-28
# Found VIIRS image for 2021-08-31
# Export started: SCAN_Silver_Sword_VIIRS_2021-08-31
# Found VIIRS image for 2021-09-05
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-05
# Found VIIRS image for 2021-09-08
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-08
# Found VIIRS image for 2021-09-13
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-13
# Found VIIRS image for 2021-09-16
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-16
# Found VIIRS image for 2021-09-21
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-21
# Found VIIRS image for 2021-09-24
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-24
# Found VIIRS image for 2021-09-29
# Export started: SCAN_Silver_Sword_VIIRS_2021-09-29
# Found VIIRS image for 2021-10-02
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-02
# Found VIIRS image for 2021-10-07
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-07
# Found VIIRS image for 2021-10-10
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-10
# Found VIIRS image for 2021-10-15
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-15
# Found VIIRS image for 2021-10-18
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-18
# Found VIIRS image for 2021-10-23
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-23
# Found VIIRS image for 2021-10-26
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-26
# Found VIIRS image for 2021-10-31
# Export started: SCAN_Silver_Sword_VIIRS_2021-10-31
# Found VIIRS image for 2021-11-03
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-03
# Found VIIRS image for 2021-11-08
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-08
# Found VIIRS image for 2021-11-11
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-11
# Found VIIRS image for 2021-11-16
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-16
# Found VIIRS image for 2021-11-19
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-19
# Found VIIRS image for 2021-11-24
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-24
# Found VIIRS image for 2021-11-27
# Export started: SCAN_Silver_Sword_VIIRS_2021-11-27
# Found VIIRS image for 2021-12-02
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-02
# Found VIIRS image for 2021-12-05
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-05
# Found VIIRS image for 2021-12-10
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-10
# Found VIIRS image for 2021-12-18
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-18
# Found VIIRS image for 2021-12-21
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-21
# Found VIIRS image for 2021-12-26
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-26
# Found VIIRS image for 2021-12-29
# Export started: SCAN_Silver_Sword_VIIRS_2021-12-29
# Found VIIRS image for 2022-01-03
# Export started: SCAN_Silver_Sword_VIIRS_2022-01-03
# Found VIIRS image for 2022-01-06
# Export started: SCAN_Silver_Sword_VIIRS_2022-01-06
# Found VIIRS image for 2022-01-11
# Export started: SCAN_Silver_Sword_VIIRS_2022-01-11
# Found VIIRS image for 2022-01-14
# Export started: SCAN_Silver_Sword_VIIRS_2022-01-14
# Found VIIRS image for 2022-01-19
# Export started: SCAN_Silver_Sword_VIIRS_2022-01-19

# %%
def load_shapefile(file_path):
    gdf = gpd.read_file(file_path)
    geom = gdf.geometry.unary_union
    return ee.Geometry(geom.__geo_interface__)  # convert to ee.Geometry

# Function to export image to Google Drive
def export_image(image, roi, filename, site):
    task = ee.batch.Export.image.toDrive(
        image=image.toFloat(),
        description=filename,
        folder= 'NDVI_'+site+"2021",  # Change folder as needed
        fileNamePrefix=filename,
        scale=500,
        region=roi.bounds(),
        crs = 'EPSG:4326',   
        maxPixels = 1e13,
        fileFormat='GeoTIFF'
    )
    task.start()
    print(f"Export started: {filename}")

# Example usage
# SCAN_Kemole_Gulch oke
# SCAN_Kukuihaele none
# SCAN_Mana_House oke
# SCAN_Silver_Sword
# SCAN_Waimea_Plain
# TAHMO_CRIG_(Soil_Moisture_Station_1)
# TAHMO_CRIG_(Soil_Moisture_Station_2)
site = 'SCAN_Silver_Sword'
shapefile_path = f"shapefiles/{site}_smap/{site}_smap_polygons.shp"
csv_path = f"daily_smap/{site}_smap.csv"
roi = load_shapefile(shapefile_path)

start_date = '2021-01-01'
end_date = '2021-02-28'

nvdi_collection = ee.ImageCollection('NASA/VIIRS/002/VNP13A1') \
                    .filterBounds(roi) \
                    .filterDate(start_date, end_date)

image_list = nvdi_collection.toList(nvdi_collection.size())

for i in range(nvdi_collection.size().getInfo()):
    image = ee.Image(image_list.get(i)).select('NDVI')
    image = image.toFloat()
    date = ee.Date(image.get('system:time_start')).format('YYYY-MM-dd').getInfo()
    export_image(image, roi, f"{site}_VIIRS_{date}", site)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /tmp/ipykernel_25817/122484514.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geom = gdf.geometry.unary_union
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-01
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-09
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-17
# Export started: SCAN_Silver_Sword_VIIRS_2021-01-25
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-02
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-10
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-18
# Export started: SCAN_Silver_Sword_VIIRS_2021-02-26

# %% [markdown]
# ### Download LST

# %%
import os
import glob
import requests
import pandas as pd
import geopandas as gpd
import ee
from datetime import datetime, timedelta

# Initialize the Earth Engine API.
ee.Authenticate(force=True)
ee.Initialize(project='ee-hadat')

# Define directories for CSV files and shapefiles.
csv_dir = 'soil_moisture_lst/soil_moisture_lst/daily_smap'
shp_base_dir = 'soil_moisture_lst/soil_moisture_lst/shapefiles'

# New folder for downloaded images.
download_base_dir = 'downloaded_images'
os.makedirs(download_base_dir, exist_ok=True)

# Get list of all CSV files in the csv_dir.
csv_files = glob.glob(os.path.join(csv_dir, '*.csv'))

def shapely_to_ee(shapely_geom):
    """Convert a Shapely geometry to an Earth Engine geometry."""
    if shapely_geom.geom_type == 'Polygon':
        coords = list(shapely_geom.exterior.coords)
        return ee.Geometry.Polygon(coords)
    elif shapely_geom.geom_type == 'MultiPolygon':
        polygons = [ee.Geometry.Polygon(list(poly.exterior.coords)) for poly in shapely_geom.geoms]
        # For simplicity, here we create a MultiPolygon from the coordinates of each polygon.
        return ee.Geometry.MultiPolygon([poly.coordinates().getInfo() for poly in polygons])
    else:
        raise ValueError("Unsupported geometry type: {}".format(shapely_geom.geom_type))

def download_gee_image(image, ee_geom, scale, output_filepath):
    """
    Download a GEE image using getDownloadURL.
    :param image: ee.Image to download.
    :param ee_geom: ee.Geometry used as region.
    :param scale: Scale (in meters) for the download.
    :param output_filepath: Local filepath to save the image.
    """
    params = {
        'scale': scale,
        'region': ee_geom.coordinates().getInfo(),
        'filePerBand': False,
        'format': 'GeoTIFF'
    }
    try:
        download_url = image.getDownloadURL(params)
        print(f"Downloading from URL: {download_url}")
        response = requests.get(download_url, stream=True)
        if response.status_code == 200:
            with open(output_filepath, 'wb') as f:
                for chunk in response.iter_content(chunk_size=1024):
                    if chunk:
                        f.write(chunk)
            print(f"Downloaded image saved to {output_filepath}")
        else:
            print(f"Failed to download image, status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading image: {e}")

def download_images_for_region(region_name, ee_geom, unique_dates, scale=1000):
    """
    For each unique date, download one image from each collection for a given region.
    Images are saved in a subfolder named after the region.
    :param region_name: Name of the region.
    :param ee_geom: Earth Engine geometry of the region.
    :param unique_dates: List or array of unique date objects.
    :param scale: Download scale in meters.
    """
    region_folder = os.path.join(download_base_dir, region_name)
    os.makedirs(region_folder, exist_ok=True)

for day in unique_dates:
        start_date = datetime.combine(day, datetime.min.time())
        end_date = start_date + timedelta(days=1)
        start_str = start_date.strftime('%Y-%m-%d')
        end_str = end_date.strftime('%Y-%m-%d')
        
        print(f"Downloading images for region '{region_name}' on {start_str}")
        
        # Filter each image collection by date and geometry.
        collection_d = ee.ImageCollection('NASA/VIIRS/002/VNP21A1D') \
            .filterDate(start_str, end_str) \
            .filterBounds(ee_geom)
        collection_n = ee.ImageCollection('NASA/VIIRS/002/VNP21A1N') \
            .filterDate(start_str, end_str) \
            .filterBounds(ee_geom)
        
        # Get the first image from each collection (if available).
        image_d = collection_d.first()
        image_n = collection_n.first()
        
        if image_d:
            output_file_d = os.path.join(region_folder, f"{start_str}_VNP21A1D.tif")
            download_gee_image(image_d, ee_geom, scale, output_file_d)
        else:
            print(f"  No VNP21A1D image found for {start_str} in region {region_name}")
        
        if image_n:
            output_file_n = os.path.join(region_folder, f"{start_str}_VNP21A1N.tif")
            download_gee_image(image_n, ee_geom, scale, output_file_n)
        else:
            print(f"  No VNP21A1N image found for {start_str} in region {region_name}")

# Main loop: Process each CSV and its corresponding shapefile.
for csv_path in csv_files:
    base_name = os.path.splitext(os.path.basename(csv_path))[0]
    print(f"\nProcessing region: {base_name}")

    # Construct the corresponding shapefile folder path.
    shp_folder = os.path.join(shp_base_dir, base_name)
    shp_files = glob.glob(os.path.join(shp_folder, '*.shp'))
    if not shp_files:
        print(f" - No shapefile found for {base_name}. Skipping.")
        continue
    shp_path = shp_files[0]  # Use the first found shapefile.
    
    # Read CSV and filter rows with valid coordinates.
    df = pd.read_csv(csv_path)
    df = df.dropna(subset=['smap_lon', 'smap_lat'])
    if df.empty:
        print(f" - No valid coordinate rows found in {base_name}.")
        continue

    try:
        df['time'] = pd.to_datetime(df['time'])
    except Exception as e:
        print(f" - Error parsing dates in {base_name}: {e}")
        continue

    unique_dates = df['time'].dt.date.unique()
    print(f" - Found {len(unique_dates)} days with coordinates.")
    
    # Read shapefile using geopandas.
    gdf = gpd.read_file(shp_path)
    union_geom = gdf.unary_union
    try:
        ee_geom = shapely_to_ee(union_geom)
    except Exception as e:
        print(f" - Error converting geometry for {base_name}: {e}")
        continue

    # Optionally: Process images in GEE (e.g., count images per day)
    for day in unique_dates:
        start_date = datetime.combine(day, datetime.min.time())
        end_date = start_date + timedelta(days=1)

# %%
import rasterio
import numpy as np

def split_s1_bands(input_path, vv_output, vh_output):
    """
    Tách bands VV và VH từ ảnh Sentinel-1A
    
    Tham số:
        input_path (str): Đường dẫn đến file ảnh đầu vào
        vv_output (str): Đường dẫn lưu band VV
        vh_output (str): Đường dẫn lưu band VH
    """
    with rasterio.open(input_path) as src:
        # Kiểm tra số lượng bands
        if src.count < 2:
            raise ValueError("Input file phải chứa ít nhất 2 bands")
            
        # Đọc metadata gốc
        meta = src.meta.copy()
        
        # Cập nhật metadata cho từng band
        vv_meta = meta.update({"count": 1, "dtype": "float32"})
        vh_meta = meta.update({"count": 1, "dtype": "float32"})

        # Ghi band VV (band 1)
        with rasterio.open(vv_output, 'w', **vv_meta) as dst:
            dst.write(src.read(1), 1)
            
        # Ghi band VH (band 2) 
        with rasterio.open(vh_output, 'w', **vh_meta) as dst:
            dst.write(src.read(2), 1)

# Cách sử dụng
split_s1_bands(
    input_path='S1A_IW_GRDH_1SDV_20230301T050000.tif',
    vv_output='VV_band.tif',
    vh_output='VH_band.tif'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12572\1841385777.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   geom = gdf.geometry.unary_union
# Found Sentinel-1 DESCENDING image for 2020-01-06
# Export started: SCAN_Kemole_Gulch_S1_2020-01-06_DESCENDING
# Found Sentinel-1 ASCENDING image for 2020-01-06
# Export started: SCAN_Kemole_Gulch_S1_2020-01-06_ASCENDING
# Found Sentinel-1 DESCENDING image for 2020-01-09
# Export started: SCAN_Kemole_Gulch_S1_2020-01-09_DESCENDING
# Found Sentinel-1 ASCENDING image for 2020-01-09
# Export started: SCAN_Kemole_Gulch_S1_2020-01-09_ASCENDING
# Found Sentinel-1 DESCENDING image for 2020-01-14
# Export started: SCAN_Kemole_Gulch_S1_2020-01-14_DESCENDING
# Found Sentinel-1 ASCENDING image for 2020-01-14
# Export started: SCAN_Kemole_Gulch_S1_2020-01-14_ASCENDING

# %%
csv_path = "daily_ave_smap/VDS_Thanatpin_smap.csv"
df = pd.read_csv(csv_path)

valid_dates = df.dropna(subset='smap_soil_moisture_am')

for index, row in valid_dates.iterrows():
    print(row['time'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2020-02-27
# 2020-03-03
# 2020-03-06
# 2020-03-11
# 2020-03-14
# 2020-03-19
# 2020-03-22
# 2020-03-27
# 2020-03-30
# 2020-04-04
# 2020-04-07
# 2020-04-12
# 2020-04-20
# 2020-04-23
# 2020-04-28
# 2020-05-01
# 2020-05-06
# 2020-05-09
# 2020-05-14
# 2020-05-17
# 2020-05-22
# 2020-05-25
# 2020-05-30
# 2020-06-02
# 2020-06-07
# 2020-06-10
# 2020-06-15
# 2020-06-18
# 2020-06-23
# 2020-06-26
# 2020-07-01
# 2020-07-04
# 2020-07-09
# 2020-07-12
# 2020-07-17
# 2020-07-20
# 2020-07-25
# 2020-07-28
# 2020-08-02
# 2020-08-05
# 2020-08-10
# 2020-08-13
# 2020-08-18
# 2020-08-21
# 2020-08-23
# 2020-08-26
# 2020-08-29
# 2020-09-03
# 2020-09-06
# 2020-10-29
# 2020-11-01
# 2020-11-06
# 2020-11-09
# 2020-11-14
# 2020-11-17
# 2020-11-22
# 2020-11-25
# 2020-11-30
# 2020-12-08
# 2020-12-11
# 2020-12-16
# 2020-12-19
# 2020-12-24
# 2020-12-27
